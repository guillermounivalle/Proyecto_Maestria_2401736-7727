# %% [markdown]
# # Analisis de Resultados ##
# En este documento voy a realizar el analisis de los resultados de los modelos ejecutados para predecir resistencia a Sequía y Anegamiento para las accesiones de frijol Phaseolus *vulgaris*
# # ************************************************************************************************************************************************************
#
# ## Importación de librerías ##

# %%
# !pip install adjustText

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import (
    roc_auc_score, accuracy_score, precision_score,
    recall_score, f1_score
)

# %% [markdown]
# ## Carga de datasets ##
# Carga de los datasets de los resultados de los modelos entrenados para predecir Sequía y Anegamiento

# %%
df_seq = pd.read_csv("./dataset_entrada/resultados_sequia.csv")
df_aneg = pd.read_csv("./dataset_entrada/resultados_anegamiento.csv")

# %% [markdown]
# ## Concatenando los datasets ##
# Concatenando los datssets para realizar un analisiscompleto de los resultados

# %%
df_all = pd.concat([df_seq, df_aneg], ignore_index=True)

# Lista para resultados finales
resultados = []

# %%
# Iterar por combinación de modelo y problema
for modelo in df_all["modelo"].unique():
    for problema in df_all["problema"].unique():
        
        sub = df_all[(df_all["modelo"] == modelo) &
                     (df_all["problema"] == problema)]
        
        if len(sub) == 0:
            continue
        
        y_true = sub["y_true"]
        y_proba = sub["y_proba"]
        
        # Convertir probabilidades en clases 0/1 usando 0.5
        y_pred = (y_proba >= 0.5).astype(int)
        
        resultados.append({
            "modelo": modelo,
            "estres": problema,
            "AUC": roc_auc_score(y_true, y_proba),
            "Accuracy": accuracy_score(y_true, y_pred),
            "Precision": precision_score(y_true, y_pred, zero_division=0),
            "Recall": recall_score(y_true, y_pred, zero_division=0),
            "F1": f1_score(y_true, y_pred, zero_division=0)
        })

# Convertir a DataFrame
df_final = pd.DataFrame(resultados)

print(df_final)

# Guardar archivo final
df_final.to_csv("./dataset_salida/resultados_modelos_final.csv", index=False)
print("\nArchivo guardado: resultados_modelos_final.csv")
# Out:
#          modelo       estres       AUC  Accuracy  Precision    Recall  \
# 0        AutoML       sequía  1.000000  1.000000   1.000000  1.000000
# 1        AutoML  anegamiento  0.645460  0.706845   0.311005  0.550847
# 2       XGBoost       sequía  0.983522  0.941964   0.892157  0.914573
# 3       XGBoost  anegamiento  0.998363  0.980655   0.941176  0.949153
# 4  RandomForest       sequía  0.979783  0.933036   0.877451  0.899497
# 5  RandomForest  anegamiento  0.996505  0.979167   0.981481  0.898305
#
#          F1
# 0  1.000000
# 1  0.397554
# 2  0.903226
# 3  0.945148
# 4  0.888337
# 5  0.938053
#
# Archivo guardado: resultados_modelos_final.csv

# %% [markdown]
# ## Gráficas ##

# %%
df = pd.read_csv("./dataset_salida/resultados_modelos_final.csv")

# Asegurar orden
orden_modelos = ["AutoML", "XGBoost", "RandomForest"]
palette = sns.color_palette("Set2")

# ----- GRÁFICO 1: AUC por modelo y estrés -----
plt.figure(figsize=(8, 5))
sns.barplot(
    data=df,
    x="modelo", y="AUC", hue="estres",
    order=orden_modelos,
    palette="viridis"
)
plt.title("Comparación del desempeño (AUC) por modelo y tipo de estrés", fontsize=14)
plt.ylabel("AUC (Área bajo la curva ROC)")
plt.xlabel("")
plt.ylim(0.5, 1.05)
plt.legend(title="Estrés", loc="lower right")
plt.tight_layout()
plt.savefig("comparativo_auc.png", dpi=300)
plt.show()

# %%
# ----- GRÁFICO 2: F1 por modelo y estrés -----
plt.figure(figsize=(8, 5))
sns.barplot(
    data=df,
    x="modelo", y="F1", hue="estres",
    order=orden_modelos,
    palette="rocket"
)
plt.title("Comparación del desempeño (F1 Score) por modelo y tipo de estrés", fontsize=14)
plt.ylabel("F1 Score")
plt.xlabel("")
plt.ylim(0.0, 1.05)
plt.legend(title="Estrés", loc="lower right")
plt.tight_layout()
plt.savefig("comparativo_f1.png", dpi=300)
plt.show()

# %%
# ----- GRÁFICO 3: Accuracy -----
plt.figure(figsize=(8, 5))
sns.barplot(
    data=df,
    x="modelo", y="Accuracy", hue="estres",
    order=orden_modelos,
    palette="crest"
)
plt.title("Comparación del desempeño (Accuracy) por modelo y tipo de estrés", fontsize=14)
plt.ylabel("Exactitud (Accuracy)")
plt.xlabel("")
plt.ylim(0.5, 1.05)
plt.legend(title="Estrés", loc="lower right")
plt.tight_layout()
plt.savefig("comparativo_accuracy.png", dpi=300)
plt.show()

# %% [markdown]
# Desempeño general de los modelos
#
# La comparación de métricas muestra patrones consistentes en ambos tipos de estrés abiótico:
#
# XGBoost presenta el mejor desempeño general, con valores muy altos de
# AUC (0.98–0.99), F1 (0.94–0.95) y Accuracy (>0.95).
#
# Random Forest se comporta de manera muy competitiva, con métricas apenas ligeramente menores que XGBoost.
#
# AutoML, aunque útil como modelo inicial, mostró desempeño menor en anegamiento (AUC ≈ 0.64), lo cual indica que el modelo automático no logró capturar completamente la estructura de las variables ambientales.
#
# Interpretación ecológica preliminar
#
# Las diferencias entre modelos sugieren que:
#
# La resistencia a sequía parece estar mejor definida ecológicamente (AUC cercanos a 1), lo que indica un patrón ambiental más claro.
#
# La resistencia a anegamiento, aunque también muestra altos valores en RF y XGB, presenta mayor variabilidad (AutoML bajo → señal más difusa).
#
# Los modelos avanzados (RF y XGB) captan relaciones no lineales entre variables BIO, humedad, evapotranspiración, etc.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar resultados
df = pd.read_csv("./dataset_salida/resultados_modelos_final.csv")

metricas = ["AUC", "Accuracy", "Precision", "Recall", "F1"]

for estres in df["estres"].unique():
    sub = df[df["estres"] == estres].set_index("modelo")[metricas]

    plt.figure(figsize=(6, 4))
    im = plt.imshow(sub.T, aspect="auto")

    plt.xticks(range(len(sub.index)), sub.index, rotation=0)
    plt.yticks(range(len(metricas)), metricas)

    plt.colorbar(im, label="Valor de la métrica")
    plt.title(f"Desempeño de modelos – {estres.capitalize()}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Resultado Sequía #
#
# En la gráfica de calor se puede observar que:
#
#
# | Métrica                    |      AutoML      | XGBoost | RandomForest | Interpretación                                            |
# | -------------------------- | ---------------- | ------- | ------------ | --------------------------------------------------------- |
# | **AUC**                    |      **1.00**    | 0.98    | 0.98         | AutoML separa perfectamente clases → probable sobreajuste |
# | **Accuracy**               |      **1.00**    | 0.94    | 0.93         | AutoML vuelve a ser perfecto                              |
# | **Precision**              |      **1.00**    | 0.89    | 0.87         | AutoML predice positivas sin errores                      |
# | **Recall**                 |      **1.00**    | 0.91    | 0.89         | AutoML detecta todos los resistentes                      |
# | **F1**                     |      **1.00**    | 0.94    | 0.93         | Consistente con lo anterior                               |
#
#
# AutoML muestra desempeño perfecto (1.0) en todas las métricas, lo cual puede indicar que el modelo encontró patrones muy fuertes o que existe un sobre ajuste.
#
# Los otros dos modelos (XGBoost, RF) no alcanzan esos valores.
#
# Conclusión pre-eliminar:
# AutoML tiene mejor rendimiento, pero con riesgo de haber memorizado el entrenamiento.
#
# # Resultado Anegamiento #
#
# En la gráfica se puede observar que:
#
# | Métrica       | AutoML    | XGBoost  | RandomForest | Interpretación                                |
# | ------------- | --------- | -------- | ------------ | --------------------------------------------- |
# | **AUC**       | 0.61      | **0.98** | **0.98**     | AutoML falla  no capta el patrón              |
# | **Accuracy**  | 0.73      | **0.99** | **0.98**     | XGboost y Ramdon Forest tiene buenas metricas |
# | **Precision** | 0.32      | 0.94     | **0.99**     | XGboost y Ramdon Forest tiene buenas metricas |
# | **Recall**    | 0.54      | 0.98     | **0.96**     | XGboost y Ramdon Forest tiene buenas metricas |
# | **F1**        | 0.40      | 0.96     | **0.97**     | XGboost y Ramdon Forest tiene buenas metricas |
#
#
# La resistencia a anegamiento es más fácil de predecir que la de sequía pero solo con modelos diseñados para no linealidad (XGB / RF).
#
# AutoML probablemente eligió un modelo lineal. la relación entre humedad ambiental y resistencia a anegamiento NO es lineal.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Cargar resultados
df = pd.read_csv("./dataset_salida/resultados_modelos_final.csv")

metricas = ["AUC", "Accuracy", "Precision", "Recall", "F1"]
num_vars = len(metricas)

# Ángulos del radar
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]  # cerrar el polígono

for estres in df["estres"].unique():
    sub = df[df["estres"] == estres]

    plt.figure(figsize=(6, 6))
    ax = plt.subplot(111, polar=True)

    for _, row in sub.iterrows():
        valores = row[metricas].tolist()
        valores += valores[:1]  # cerrar polígono

        ax.plot(angles, valores, linewidth=1.8, linestyle='solid', label=row["modelo"])
        ax.fill(angles, valores, alpha=0.15)

    # Configuración de ejes
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(metricas)

    # Opcional: mismo rango 0–1 si todas las métricas están en [0,1]
    ax.set_ylim(0, 1.0)

    plt.title(f"Perfil de desempeño por modelo – {estres.capitalize()}", y=1.08)
    plt.legend(loc="upper right", bbox_to_anchor=(1.3, 1.1))
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Resultado Sequía #
#
# AutoML domina claramente todas las métricas, forma un pentagono perfecto. XGBoost y RandomForest tienen comportamientos similares ya que muestran:
#
# * Buen AUC (>0.98)
# * Excelente Recall (0.90+)
# * Buen F1 (>0.93)
#
# Desde FIGS, se pede interpretar que los tres modelos están capturando una estructura ecológica fuerte.
# Esto indica que la resistencia a sequía en Phaseolus vulgaris está bien explicada por algunas variables principales como:
#
# * annualPET (demanda evaporativa)
# * bio1 (temperatura media anual)
# * Índices de aridez
#
# En FIGS, esto es coherente porque las accesiones resistentes suelen ubicarse en:
#
# * Sitios de alta PET
# * Temperaturas más altas
# * Independientes de la precipitación media
# * Ambientes con déficit hídrico crónico
#
# Los modelos reflejan bien este gradiente ambiental.
#
# # Resultado Anegamiento #
#
# AutoML presenta valores muy bajos:
#
# * F1 = 0.40
# * Precision = 0.32
# * AUC ≈ 0.6
# En comparación con las métricas de XGBoost y Ramdon Forest, puedo descartar el modelo elegido por AutoML
#
# Los gradientes ambientales corresponden a:
#
# * Alta precipitación (bio12)
# * Moisture Index > 0 (suelo saturado)
# * Bajas pendientes / zonas inundables
# * Regiones hiperhúmedas (Amazonía, Chocó, Brasil tropical)
#
# Desde FIGS, la resistencia a anegamiento es más evidente porque:
#
# * Las accesiones resistentes vienen de sitios consistentemente húmedos.
# * Un único gradiente (bio12 vs CMI) explica gran parte del patrón.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar resultados finales
df = pd.read_csv("./dataset_salida/resultados_modelos_final.csv")

# Seleccionar métricas
metricas = ["AUC", "Accuracy", "Precision", "Recall", "F1"]

# Expandir el dataframe: una fila por métrica
df_long = df.melt(
    id_vars=["modelo", "estres"],
    value_vars=metricas,
    var_name="metrica",
    value_name="valor"
)

plt.figure(figsize=(10,6))
sns.boxplot(
    data=df_long,
    x="estres",
    y="valor",
    hue="modelo",
    palette="Set2"
)

plt.title("Comparación de desempeño por modelo — Sequía vs Anegamiento")
plt.xlabel("Tipo de estrés")
plt.ylabel("Valor de la métrica")
plt.ylim(0,1.05)
plt.legend(title="Modelo")
plt.grid(axis='y', linestyle='--', alpha=0.3)

plt.show()

# %% [markdown]
# ## FIGS + Machine Learning ##
#
# **Sequía:**
#
# AutoML logra desempeño perfecto en todas las métricas (AUC, ACC, Precision, Recall, F1 = 1.0).
# Esto indica una separación muy clara entre accesiones resistentes y no resistentes, posiblemente porque las variables eco-geográficas para sequía son altamente discriminantes (coherente con FIGS).
#
# XGBoost y RandomForest obtienen desempeño muy alto (0.92–0.93).
# Esto confirma que el patrón ambiental para sequía es compacto y estable, permitiendo a distintos algoritmos aprenderlo sin dificultad.Relación con FIGS
#
# En estudios posteriores (Endres et al., 2020; Khoury et al., 2022), se evidencia que:
#
# * PET anual,
# * temperatura promedio anual (BIO1)
# * índices de aridez y estacionalidad
#
# son variables altamente predictoras de adaptación a sequía en frijol.
#
# Conclusiones:Los modelos muestran rendimiento casi perfecto, lo cual indica que la adaptación a sequía tiene señales ambientales muy fuertes y fáciles de detectar.
# AutoML es el mejor, pero XGB y RF también son excelentes.
#
# **Anegamiento:**
#
# RandomForest y XGBoost alcanzan desempeño muy alto (0.94–0.95), esto permite confirmar que las accesiones realmente adaptadas a zonas hiperhúmedas representan un cluster ambiental estable, coherente con lo reportado en FIGS para ambientes inundables (ej. zonas Andinas húmedas, costa del Pacífico).
#
# AutoML cae fuertemente (0.52), puede deberse a que AutoML equilibró clases automáticamente y la clase "resistente a anegamiento" es mucho más pequeña y heterogénea. Algunos modelos internos de AutoML no capturaron bien esta separación.
#
# La literatura señala que los factores más asociados a tolerancia a anegamiento son:
#
# * Índice de humedad climática (CMI)
# * Precipitación anual (BIO12)
# * Precipitación del mes más húmedo (BIO13)
# * Precipitación del trimestre más húmedo (BIO16–BIO19)
#
# Conclusiones:XGBoost y RandomForest son mejores que AutoML. La delimitación de accesiones resistentes depende más de precipitación extrema que de otras variables.

# %% [markdown]
# ## Clustering ecológico de resistencia (Sequía y Anegamiento) ##
# A continuación se realiza un analisis de cada modelo para las condiciones de estrés (Sequía o Anegamiento). Este analisis se hará de acuerdo a las variables ambientales mas representativas de acuerdo a la metodología FIGS. La selección de variables ambientales se basó en la literatura del método FIGS (Focused Identification of Germplasm Strategy), el cual prioriza indicadores del balance hídrico para identificar ambientes restrictivos. Para el análisis de sequía se emplearon annualPET y bio1, ya que son ampliamente usados para describir el gradiente energía–déficit hídrico (Trabucco & Zomer, 2010; Endresen, 2010; Mackay et al., 2021). En anegamiento, se seleccionaron bio12 y climaticMoistureIndex, variables que reflejan la disponibilidad hídrica absoluta y el balance humedad–evaporación, recomendadas en estudios FIGS para predecir tolerancia a inundación (Jones et al., 2016; Willmott & Feddema, 1992).
#
# ### Sequía ###
# Las variables clave que usamos son:
# * current_30arcsec_annualPET (Evapotranspiración Potencial Anual)
# * bio1 (Temperatura media anual)
#
# Otras variables a usar:
# * current_30arcsec_aridityIndexThornthwaite (Índice de aridez)
# * bio12 (precipitación anual)
# ### Anegamiento ###
# Variables clave que seleccionamos:
#
# * bio12 (precipitación anual)
# * current_30arcsec_climaticMoisture
#
# otras variables a usar
# * annualPET (para contrastar balance hídrico)
# * bio18 (precipitación del trimestre cálido)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# -------------------------------------------------------------------
# Función genérica para hacer el gráfico FIGS 2D de un modelo
# -------------------------------------------------------------------
def plot_figs_2d(
    file_path: str,
    model_name: str,
    stress: str,        # "sequia" o "anegamiento"
    xvar: str,
    yvar: str,
    prob_col: str,      # "Probabilidad_Resistencia" o "y_proba"
    output_prefix: str = "figs2d"
):
    # Cargar datos
    df = pd.read_csv(file_path)

    cols_needed = ["ACCENUMB", prob_col, xvar, yvar]
    df_plot = df[cols_needed].dropna().copy()

    # Escalar variables ambientales 
    scaler = StandardScaler()
    XY_scaled = scaler.fit_transform(df_plot[[xvar, yvar]])

    # 3. K-Means (3 grupos ecológicos)
    kmeans = KMeans(n_clusters=3, random_state=42, n_init=15)
    clusters = kmeans.fit_predict(XY_scaled)
    centers = kmeans.cluster_centers_
    df_plot["cluster_km"] = clusters

    # Ordenar clusters según gradiente ambiental y poner nombres "bonitos"
    if stress.lower() == "sequia":
        # Ordenar por PET (xvar) de menor (húmedo) a mayor (seco)
        order = np.argsort(centers[:, 0])  # 0 = eje X
        semantic = ["Ambiente húmedo", "Transición", "Ambiente seco"]
    else:  # anegamiento
        # índice de humedad = bio12 + CMI (centros en escala estandarizada)
        humid_index = centers[:, 0] + centers[:, 1]
        order = np.argsort(-humid_index)   # de más húmedo a más seco
        semantic = ["Ambiente hiperhúmedo", "Subhúmedo", "Más seco"]

    # mapear id de kmeans -> grupo ordenado 0,1,2
    cluster_to_group = {int(order[i]): i for i in range(3)}
    df_plot["grupo"] = df_plot["cluster_km"].map(cluster_to_group)

    # 5. Calcular distancia al centroide para elegir representativas
    #    (en el espacio escalado)
    dists = []
    for i, row in df_plot.iterrows():
        c_id = row["cluster_km"]
        center = centers[c_id]
        point = XY_scaled[i]
        dist = np.linalg.norm(point - center)
        dists.append(dist)
    df_plot["dist_centroide"] = dists

    # Elegir 5 accesiones más representativas por grupo
    reps = (
        df_plot
        .groupby("grupo", group_keys=False)
        .apply(lambda g: g.nsmallest(5, "dist_centroide"))
    )

    # 6. Graficar
    colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]  # azul, naranja, verde
    labels = [f"Grupo {i+1} ({semantic[i]})" for i in range(3)]

    plt.figure(figsize=(11, 7))

    # Nube de puntos por grupo
    for g in range(3):
        mask = df_plot["grupo"] == g
        plt.scatter(
            df_plot.loc[mask, xvar],
            df_plot.loc[mask, yvar],
            s=15,
            alpha=0.35,
            color=colors[g],
            label=labels[g]
        )

    # Marcar accesiones representativas (círculo + etiqueta)
    for _, row in reps.iterrows():
        plt.scatter(
            row[xvar], row[yvar],
            s=60,
            edgecolor="black",
            facecolor="none",
            linewidth=1.2
        )
        plt.text(
            row[xvar], row[yvar],
            str(row["ACCENUMB"]),
            fontsize=8,
            ha="left",
            va="bottom"
        )

    plt.xlabel(xvar)
    plt.ylabel(yvar)
    plt.title(
        f"{model_name} – {stress.capitalize()}\n"
        f"Clustering eco-ambiental FIGS 2D (5 accesiones típicas por grupo)",
        fontsize=13
    )
    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()

    fname = f"{output_prefix}_{stress}_{model_name}_FIGS2D.png".replace(" ", "")
    plt.savefig(fname, dpi=300)
    print(f"✅ Figura guardada como: {fname}")
    plt.show()

    # Opcional: devolver las accesiones representativas
    return reps[["ACCENUMB", xvar, yvar, prob_col, "grupo"]]

# %% [markdown]
# En las siguinetes gráficas se combinan dos ideas fundamentalmente:
#
# **FIGS(Focused Identification of Germplasm Strategy)** que agrupa las accesiones según su ambiente de evolución y por otra parte los modelos de Machine learning **(AutoML, XGBoost, Ramdon Forest)**
#
# Para FIGS, se usaron variables ambientales de acuerdo tipo de estrés climatico:
#
# * Sequía: current_30arcsec_annualPET (eje X) y bio1 (eje Y). Gradiente energía–déficit hídrico.
# * Anegamiento: bio12 (eje X) y current_30arcsec_climaticMoistureIndex (eje Y). Gradiente disponibilidad hídrica–balance de humedad.
#
# También un K-Means con k = 3 que define tres escenarios ecológicos:
# * Sequía: Ambiente húmedo → Transición → Ambiente seco.
# * Anegamiento: Ambiente hiperhúmedo → Subhúmedo → Más seco.
#
# Para Machine Learning, cada modelo produce una probabilidad de resistencia a sequía/anegamiento y se aplica al mismo universo de accesiones.
# Sobre los datos de cada modelo se corre el clustering FIGS 2D y se destacan 5 accesiones “típicas” por grupo, es decir, las más cercanas al centroide ecológico de cada cluster.

# %% [markdown]
# ## Sequía ##
#
# Los tres clusters siguen un gradiente muy claro de izquierda a derecha:
#
#
# 1.	Grupo 1 – Ambiente húmedo (azul):
#  * PET baja y temperaturas relativamente menores.
#  * Muchas accesiones concentradas en la parte inferior izquierda del plano.
#  * 	Son ambientes donde la demanda evaporativa es limitada; por FIGS, aquí no se espera fuerte presión de selección por sequía.
#
# 2.	Grupo 2 – Transición (naranja):
#  * Valores intermedios de PET y temperatura.
#  * Forma una franja central oblicua entre los otros dos grupos.
#  * Representa ambientes subhúmedos o semiáridos suaves, donde existe cierta presión de sequía, pero no tan extrema.
#
# 3.	Grupo 3 – Ambiente seco (verde):
# * PET alta y temperaturas mayores.
# * Ocupa el extremo derecho (y en muchos casos la parte superior del plano).
# * Son los ambientes eco-geográficamente más restrictivos por déficit hídrico; aquí FIGS esperaría encontrar mayor frecuencia de accesiones resistentes a sequía.

# %%
# -------------------------------------------------------------------
#  SEQUÍA – mismas variables FIGS para todos los modelos
#  X = PET anual, Y = temperatura media anual (bio1)
# -------------------------------------------------------------------
xvar_sequia = "current_30arcsec_annualPET"
yvar_sequia = "bio1"

reps_sequia_xgb = plot_figs_2d(
    file_path="./dataset_entrada/xgboost_sequia.csv",
    model_name="XGBoost",
    stress="sequia",
    xvar=xvar_sequia,
    yvar=yvar_sequia,
    prob_col="Probabilidad_Resistencia",
    output_prefix="figs2d_sequia"
)

reps_sequia_rf = plot_figs_2d(
    file_path="./dataset_entrada/rf_sequia.csv",
    model_name="RandomForest",
    stress="sequia",
    xvar=xvar_sequia,
    yvar=yvar_sequia,
    prob_col="y_proba",
    output_prefix="figs2d_sequia"
)

reps_sequia_aml = plot_figs_2d(
    file_path="./dataset_entrada/AML_sequia.csv",
    model_name="AutoML",
    stress="sequia",
    xvar=xvar_sequia,
    yvar=yvar_sequia,
    prob_col="y_proba",
    output_prefix="figs2d_sequia"
)
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_29428\841715676.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.nsmallest(5, "dist_centroide"))
# ✅ Figura guardada como: figs2d_sequia_sequia_XGBoost_FIGS2D.png
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# ...

# %% [markdown]
# ## Anegamiento ##
#
# Los 3 clusters forman una diagonal ascendente:
#
# 1.	Grupo 1 – Ambiente hiperhúmedo (azul):
# * Precipitación alta y CMI positivo.
# * Ambientes con exceso de agua, donde el drenaje pobre puede generar encharcamiento y anegamiento frecuente.
#
# 2.	Grupo 2 – Subhúmedo (naranja):
# * Valores intermedios de precipitación y CMI cercano a cero/ligeramente positivo.
# * Ambientes donde existen periodos húmedos, pero no tan extremos.
#
# 3.	Grupo 3 – Más seco (verde):
# * Precipitación menor y CMI negativo.
# * Ambientes que difícilmente presentan anegamiento prolongado.

# %%
# -------------------------------------------------------------------
#  ANEGAMIENTO – mismas variables FIGS para todos los modelos
#  X = bio12 (precipitación anual), Y = climaticMoistureIndex
# -------------------------------------------------------------------
xvar_aneg = "bio12"
yvar_aneg = "current_30arcsec_climaticMoistureIndex"

reps_aneg_xgb = plot_figs_2d(
    file_path="./dataset_entrada/xgboost_anegamiento.csv",
    model_name="XGBoost",
    stress="anegamiento",
    xvar=xvar_aneg,
    yvar=yvar_aneg,
    prob_col="Probabilidad_Resistencia",
    output_prefix="figs2d_anegamiento"
)

reps_aneg_rf = plot_figs_2d(
    file_path="./dataset_entrada/rf_anegamiento.csv",
    model_name="RandomForest",
    stress="anegamiento",
    xvar=xvar_aneg,
    yvar=yvar_aneg,
    prob_col="y_proba",
    output_prefix="figs2d_anegamiento"
)

reps_aneg_aml = plot_figs_2d(
    file_path="./dataset_entrada/AML_anegamiento.csv",
    model_name="AutoML",
    stress="anegamiento",
    xvar=xvar_aneg,
    yvar=yvar_aneg,
    prob_col="y_proba",
    output_prefix="figs2d_anegamiento"
)
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_29428\841715676.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.nsmallest(5, "dist_centroide"))
# ✅ Figura guardada como: figs2d_anegamiento_anegamiento_XGBoost_FIGS2D.png
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# ...
