# %% [markdown]
# # Definiendo el mejor modelo
# Ahora que ya tengo las variables, procedo a probar y a definir cuál es el mejor modelo predicción usando metodología FIGS.
# La metodología FIGS (Focused Identification of Germplasm Strategy) parte de un principio clave:
#
# *Los ambientes donde fueron colectadas las accesiones explican, en parte, su adaptación a condiciones extremas (como sequía o exceso de agua).*
#
# Para los modelos a usar, he definidio crear una variable objetivo llamada "resistente a sequía". Esta variable será de valor binario (1/0) y se genera a partir de los datos del ambiente histórico donde se colectó la accesión.
# * **Resistente a sequía** = Accesiones colectadas en ambientes áridos o con baja precipitación y alta evapotranspiración.
# * **No resistente** = Ambientes húmedos, con alta humedad o baja aridez.
#
#
# # Esta parte por editar
# En este caso las variables que usaré para crear la variable objetivo son:
# * Precipitación anual (bio12)
# * Precipitación del trimestre más seco (bio17)
# * Temperatura máxima del mes más cálido (bio5)
# * Índice de aridez (current_30arcsec_aridityIndexThornthwaite)
# * Índice de humedad climática (current_30arcsec_climaticMoistureIndex)
# * Evapotranspiración potencial (current_30arcsec_annualPET)
#
# # ************************************************************************************************************************************************************

# %% [markdown]
# ## Importando Librerías ##
# # ************************************************************************************************************************************************************

# %%
import h2o
from h2o.automl import H2OAutoML
import pandas as pd
import numpy as np

# %%
h2o.cluster().shutdown()
# Out:
# H2O session _sid_b56b closed.

# %%
# Inicializar el clúster local de H2O
h2o.init(max_mem_size="16G")
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM 18.9 (build 11.0.20+9-LTS-256, mixed mode)
#   Starting server from C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\guill\AppData\Local\Temp\tmp3yoxl5ac
#   JVM stdout: C:\Users\guill\AppData\Local\Temp\tmp3yoxl5ac\h2o_guill_started_from_python.out
#   JVM stderr: C:\Users\guill\AppData\Local\Temp\tmp3yoxl5ac\h2o_guill_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# Warning: Your H2O cluster version is (7 months and 11 days) old.  There may be a newer version available.
# Please download and install the latest version from: https://h2o-release.s3.amazonaws.com/h2o/latest_stable.html
# --------------------------  -----------------------------
# H2O_cluster_uptime:         04 secs
# H2O_cluster_timezone:       America/Bogota
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.7
# H2O_cluster_version_age:    7 months and 11 days
# H2O_cluster_name:           H2O_from_python_guill_z33ulh
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    16 Gb
# H2O_cluster_total_cores:    16
# H2O_cluster_allowed_cores:  16
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.12.4 final
# --------------------------  -----------------------------

# %% [markdown]
# ## Paso 1 Carga del dataset ##
# # ************************************************************************************************************************************************************

# %%
# ==========================================
# CARGA Y REVISIÓN DEL DATASET
# ==========================================

# Cargar el archivo
df = pd.read_csv("./dataset_entrada/dataset_reducido_no_colineal.csv")

# Mostrar información general
print("Dimensiones:", df.shape)
print("\nPrimeras filas:")
display(df.head())

print("\nResumen de tipos de datos y nulos:")
display(df.info())
# Out:
# Dimensiones: (3357, 67)
#
# Primeras filas:
#               DOI ACCENUMB CURATION      GENUS   SPECIES           GRIN_NAME  \
# 0  10.18730/JKECH   G16570     FULL  Phaseolus  vulgaris  Phaseolus vulgaris
# 1  10.18730/JKEKR   G16576     FULL  Phaseolus  vulgaris  Phaseolus vulgaris
# 2  10.18730/JZXX0     G990     FULL  Phaseolus  vulgaris  Phaseolus vulgaris
# 3  10.18730/JZXWU     G989     FULL  Phaseolus  vulgaris  Phaseolus vulgaris
# 4  10.18730/JZXT$     G987     FULL  Phaseolus  vulgaris  Phaseolus vulgaris
#
#   ORIGCTY                                         COLLSITE  DECLATITUDE  \
# 0     IRN                                  KARAJ - MARKAZI        35.81
# 1     IRN  KERMANSHAH CHAMCHAL - KERMANSHAH - KERMANSHAHAN        34.32
# 2     IRN                                AHWAZ - KHUZESTAN        31.32
# 3     IRN                                   KAZERUN - FARS        29.62
# 4     IRN                                    SHIRAZ - FARS        29.60
#
#    DECLONGITUDE  ...    prec_6    prec_7    srad_1   srad_10    srad_3  \
# 0         50.93  ... -1.062011 -1.045993 -1.131852 -0.559309 -0.926190
# 1         47.07  ... -1.109707 -1.073673 -1.154124 -0.067053 -0.746152
# 2         48.70  ... -1.128786 -1.082899 -0.781826  0.306394 -0.175266
# 3         51.63  ... -1.128786 -1.082899 -0.363673  0.921358  0.203504
# 4         52.53  ... -1.119246 -1.073673 -0.417170  1.029527  0.073796
#
#      srad_4    srad_5    srad_9    wind_1   wind_10
# 0 -0.166400  0.805037  1.113787 -0.158827  0.322904
# 1 -0.220326  0.879623  2.107256 -0.372930  0.322904
# 2  0.335804  1.118016  2.205778  0.162328  0.064891
# 3  0.689795  1.501642  2.629266 -0.158827 -0.064115
# 4  0.454904  1.196261  2.629266 -0.051775 -0.064115
#
# [5 rows x 67 columns]
# Resumen de tipos de datos y nulos:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3357 entries, 0 to 3356
# Data columns (total 67 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   DOI                                        3357 non-null   object
#  1   ACCENUMB                                   3357 non-null   object
#  2   CURATION                                   3357 non-null   object
#  3   GENUS                                      3357 non-null   object
#  4   SPECIES                                    3357 non-null   object
#  5   GRIN_NAME                                  3357 non-null   object
#  6   ORIGCTY                                    3357 non-null   object
#  7   COLLSITE                                   3357 non-null   object
#  8   DECLATITUDE                                3357 non-null   float64
#  9   DECLONGITUDE                               3357 non-null   float64
#  10  SAMPSTAT                                   3357 non-null   float64
#  11  ELEVATION                                  3357 non-null   float64
#  12  COLLSRC                                    3357 non-null   float64
#  13  MODCF_CloudForestPrediction                3357 non-null   float64
#  14  MODCF_meanannual                           3357 non-null   float64
#  15  MODCF_seasonality_concentration            3357 non-null   float64
#  16  current_30arcsec_annualPET                 3357 non-null   float64
#  17  current_30arcsec_aridityIndexThornthwaite  3357 non-null   float64
#  18  current_30arcsec_climaticMoistureIndex     3357 non-null   float64
#  19  current_30arcsec_continentality            3357 non-null   float64
#  20  AWCh1_M_sl1                                3357 non-null   float64
#  21  AWCh1_M_sl2                                3357 non-null   float64
#  22  AWCtS_M_sl1                                3357 non-null   float64
#  23  CECSOL_M_sl1                               3357 non-null   float64
#  24  CECSOL_M_sl2                               3357 non-null   float64
#  25  CLYPPT_M_sl1                               3357 non-null   float64
#  26  CRFVOL_M_sl1                               3357 non-null   float64
#  27  BDRICM_M                                   3357 non-null   float64
#  28  ORCDRC_M_sl1                               3357 non-null   float64
#  29  ORCDRC_M_sl2                               3357 non-null   float64
#  30  OCDENS_M_sl1                               3357 non-null   float64
#  31  OCSTHA_M_sd1                               3357 non-null   float64
#  32  PHIHOX_M_sl1                               3357 non-null   float64
#  33  PHIKCL_M_sl1                               3357 non-null   float64
#  34  BDRLOG_M                                   3357 non-null   float64
#  35  SNDPPT_M_sl1                               3357 non-null   float64
#  36  SLTPPT_M_sl1                               3357 non-null   float64
#  37  SLGWRB                                     3357 non-null   float64
#  38  WWP_M_sl1                                  3357 non-null   float64
#  39  ACDWRB_M_ss                                3357 non-null   float64
#  40  bio1                                       3357 non-null   float64
#  41  bio10                                      3357 non-null   float64
#  42  bio12                                      3357 non-null   float64
#  43  bio13                                      3357 non-null   float64
#  44  bio14                                      3357 non-null   float64
#  45  bio15                                      3357 non-null   float64
#  46  bio18                                      3357 non-null   float64
#  47  bio19                                      3357 non-null   float64
#  48  bio2                                       3357 non-null   float64
#  49  bio3                                       3357 non-null   float64
#  50  bio8                                       3357 non-null   float64
#  51  bio9                                       3357 non-null   float64
#  52  prec_1                                     3357 non-null   float64
#  53  prec_10                                    3357 non-null   float64
#  54  prec_11                                    3357 non-null   float64
#  55  prec_4                                     3357 non-null   float64
#  56  prec_5                                     3357 non-null   float64
#  57  prec_6                                     3357 non-null   float64
#  58  prec_7                                     3357 non-null   float64
#  59  srad_1                                     3357 non-null   float64
#  60  srad_10                                    3357 non-null   float64
#  61  srad_3                                     3357 non-null   float64
#  62  srad_4                                     3357 non-null   float64
#  63  srad_5                                     3357 non-null   float64
#  64  srad_9                                     3357 non-null   float64
#  65  wind_1                                     3357 non-null   float64
#  66  wind_10                                    3357 non-null   float64
# dtypes: float64(59), object(8)
# memory usage: 1.7+ MB
# None

# %%
# ============================================================
# Crear variable objetivo (simplificada para prueba inicial)
# ============================================================

# Lógica: valores bajos de aridez (menos estrés), PET y CMI intermedios
df["Resistencia_Sequia"] = np.where(
    (df["current_30arcsec_aridityIndexThornthwaite"] < df["current_30arcsec_aridityIndexThornthwaite"].median()) &
    (df["current_30arcsec_annualPET"] < df["current_30arcsec_annualPET"].median()) &
    (df["current_30arcsec_climaticMoistureIndex"] > df["current_30arcsec_climaticMoistureIndex"].median()),
    1, 0
)

# Verificar balance de clases
print(df["Resistencia_Sequia"].value_counts(normalize=True))
# Out:
# Resistencia_Sequia
# 0    0.704498
# 1    0.295502
# Name: proportion, dtype: float64

# %% [markdown]
# ## Eliminando Columnas ##
# Elimino las columnas que use para crear la variable objetivo. Esto lo hago porque al entrenar los modelos ya saben la respuesta antes de entrenar, porque la variable objetivo fue calculada directamente con esas columnas.
# # ************************************************************************************************************************************************************

# %%
df = df.drop(columns=['current_30arcsec_aridityIndexThornthwaite', 'current_30arcsec_annualPET', 'current_30arcsec_climaticMoistureIndex'])

# %%
# Convertir a H2OFrame
hf = h2o.H2OFrame(df)

# Definir variables predictoras y objetivo
y = "Resistencia_Sequia"
x = [col for col in hf.columns if col not in [y]]

# Verificar dimensiones
hf.describe()
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Rows:3357
# Cols:65
#          DOI             ACCENUMB    CURATION    GENUS      SPECIES    GRIN_NAME           ORIGCTY    COLLSITE                                         DECLATITUDE         DECLONGITUDE      SAMPSTAT                 ELEVATION              COLLSRC                 MODCF_CloudForestPrediction    MODCF_meanannual       MODCF_seasonality_concentration    current_30arcsec_continentality    AWCh1_M_sl1            AWCh1_M_sl2              AWCtS_M_sl1            CECSOL_M_sl1            CECSOL_M_sl2           CLYPPT_M_sl1            CRFVOL_M_sl1            BDRICM_M                ORCDRC_M_sl1             ORCDRC_M_sl2             OCDENS_M_sl1            OCSTHA_M_sd1            PHIHOX_M_sl1            PHIKCL_M_sl1            BDRLOG_M                SNDPPT_M_sl1            SLTPPT_M_sl1            SLGWRB                  WWP_M_sl1               ACDWRB_M_ss            bio1                    bio10                  bio12                  bio13                  bio14                   bio15                   bio18                    bio19                  bio2                    bio3                     bio8                     bio9                    prec_1                prec_10                 prec_11                  prec_4                 prec_5                 prec_6               prec_7                   srad_1                  srad_10                 srad_3                  srad_4                  srad_5                  srad_9                  wind_1                 wind_10                  Resistencia_Sequia
# -------  --------------  ----------  ----------  ---------  ---------  ------------------  ---------  -----------------------------------------------  ------------------  ----------------  -----------------------  ---------------------  ----------------------  -----------------------------  ---------------------  ---------------------------------  ---------------------------------  ---------------------  -----------------------  ---------------------  ----------------------  ---------------------  ----------------------  ----------------------  ----------------------  -----------------------  -----------------------  ----------------------  ----------------------  ----------------------  ----------------------  ----------------------  ----------------------  ----------------------  ----------------------  ----------------------  ---------------------  ----------------------  ---------------------  ---------------------  ---------------------  ----------------------  ----------------------  -----------------------  ---------------------  ----------------------  -----------------------  -----------------------  ----------------------  --------------------  ----------------------  -----------------------  ---------------------  ---------------------  -------------------  -----------------------  ----------------------  ----------------------  ----------------------  ----------------------  ----------------------  ----------------------  ---------------------  -----------------------  --------------------
# type     string          string      enum        enum       enum       enum                enum       string                                           real                real              real                     real                   real                    real                           real                   real                               real                               real                   real                     real                   real                    real                   real                    real                    real                    real                     real                     real                    real                    real                    real                    real                    real                    real                    real                    real                    real                   real                    real                   real                   real                   real                    real                    real                     real                   real                    real                     real                     real                    real                  real                    real                     real                   real                   real                 real                     real                    real                    real                    real                    real                    real                    real                   real                     int
# mins     NaN             NaN                                                                          NaN                                              -38.03              -123.25           -2.9470184280009937      -1.7313909480576033    -2.902539935203636      -0.6180967779415024            -2.67806184905012      -1.5377304677436885                -1.013669472717795                 -4.549472427604171     -5.82647884809277        -2.8030046663244432    -2.3445427990812053     -2.626026170769608     -3.5844189665303188     -1.4958970187309133     -4.838701570648681      -1.4874469887424702      -1.3472192862608754      -1.9701529294531743     -2.111182666237144      -2.273661691754548      -3.457293271262553      -1.353287997233943      -3.424942477539436      -3.146616838708615      -0.1099513511812154     -4.055672494013865      -1.1698836982734446    -3.7146582266803474     -4.131771819329132     -1.8210489181806069    -1.8480900176832689    -0.8120047329490826     -2.0539501084581486     -1.6251302951078737      -0.8754433635726453    -2.4435380181441726     -2.218648539160718       -4.269567131925109       -5.596865965711562      -0.9902473241872196   -1.2139897223537115     -1.1002297895954634      -1.1071331609448072    -1.1939927653545588    -1.1287855512562417  -1.0828993213351026      -2.563834629222031      -3.48588665563591       -2.690042873671915      -2.5755243544497777     -3.5341791761848587     -3.6740562744026937     -1.8716521379977928    -1.870203465268774       0.0
# [3357 rows x 65 columns]

# %%
# Asegurar tipo categórico en todo el dataset
y = "Resistencia_Sequia"
hf[y] = hf[y].asfactor()

# Confirmar tipo
print(hf.types)
# Out:
# {'DOI': 'string', 'ACCENUMB': 'string', 'CURATION': 'enum', 'GENUS': 'enum', 'SPECIES': 'enum', 'GRIN_NAME': 'enum', 'ORIGCTY': 'enum', 'COLLSITE': 'string', 'DECLATITUDE': 'real', 'DECLONGITUDE': 'real', 'SAMPSTAT': 'real', 'ELEVATION': 'real', 'COLLSRC': 'real', 'MODCF_CloudForestPrediction': 'real', 'MODCF_meanannual': 'real', 'MODCF_seasonality_concentration': 'real', 'current_30arcsec_continentality': 'real', 'AWCh1_M_sl1': 'real', 'AWCh1_M_sl2': 'real', 'AWCtS_M_sl1': 'real', 'CECSOL_M_sl1': 'real', 'CECSOL_M_sl2': 'real', 'CLYPPT_M_sl1': 'real', 'CRFVOL_M_sl1': 'real', 'BDRICM_M': 'real', 'ORCDRC_M_sl1': 'real', 'ORCDRC_M_sl2': 'real', 'OCDENS_M_sl1': 'real', 'OCSTHA_M_sd1': 'real', 'PHIHOX_M_sl1': 'real', 'PHIKCL_M_sl1': 'real', 'BDRLOG_M': 'real', 'SNDPPT_M_sl1': 'real', 'SLTPPT_M_sl1': 'real', 'SLGWRB': 'real', 'WWP_M_sl1': 'real', 'ACDWRB_M_ss': 'real', 'bio1': 'real', 'bio10': 'real', 'bio12': 'real', 'bio13': 'real', 'bio14': 'real', 'bio15': 'real', 'bio18': 'real', 'bio19': 'real', 'bio2': 'real', 'bio3': 'real', 'bio8': 'real', 'bio9': 'real', 'prec_1': 'real', 'prec_10': 'real', 'prec_11': 'real', 'prec_4': 'real', 'prec_5': 'real', 'prec_6': 'real', 'prec_7': 'real', 'srad_1': 'real', 'srad_10': 'real', 'srad_3': 'real', 'srad_4': 'real', 'srad_5': 'real', 'srad_9': 'real', 'wind_1': 'real', 'wind_10': 'real', 'Resistencia_Sequia': 'enum'}

# %%
# División de datos (70% entrenamiento / 30% prueba)
train, test = hf.split_frame(ratios=[0.7], seed=42)

# Separar predictores y variable objetivo (ajusta el nombre exacto)
y_col = "Resistencia_Sequia"
X_cols = [c for c in test.columns if c != y_col]
# Convertir a DataFrame de pandas
X_test = test[X_cols].as_data_frame()
y_test = test[y_col].as_data_frame()

# Crear carpeta de salida (si no existe)
import os
os.makedirs("./dataset_salida", exist_ok=True)

# Guardar los archivos CSV
X_test.to_csv("./dataset_salida/X_test_AML_sequia.csv", index=False)
y_test.to_csv("./dataset_salida/y_test_AML_sequia.csv", index=False)
# Out:
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"

# %%
# ============================================================
# Ejecución de AutoML (modelo automático)
# ============================================================

# Definir el experimento
aml = H2OAutoML(
    max_models=10,        # cantidad de modelos a probar
    seed=42,              # reproducibilidad
    max_runtime_secs=600, # duración total (10 min)
    balance_classes=True  # balancear clases 1/0
)

# Entrenar el modelo
aml.train(x=x, y=y, training_frame=hf)

# Mostrar el leaderboard (ranking de modelos)
lb = aml.leaderboard
lb.head(rows=10)
# Out:
# AutoML progress: |
# 19:16:02.428: AutoML: XGBoost is not available; skipping it.
# 19:16:02.466: _train param, Dropping bad and constant columns: [SPECIES, GRIN_NAME, COLLSITE, ACCENUMB, DOI, GENUS]
#
# █
# 19:16:04.821: _train param, Dropping bad and constant columns: [SPECIES, GRIN_NAME, COLLSITE, ACCENUMB, DOI, GENUS]
#
# ████
# 19:16:14.470: _train param, Dropping bad and constant columns: [SPECIES, GRIN_NAME, COLLSITE, ACCENUMB, DOI, GENUS]
#
# █
# 19:16:19.356: _train param, Dropping bad and constant columns: [SPECIES, GRIN_NAME, COLLSITE, ACCENUMB, DOI, GENUS]
#
# █
# 19:16:24.305: _train param, Dropping bad and constant columns: [SPECIES, GRIN_NAME, COLLSITE, ACCENUMB, DOI, GENUS]
#
# ██
# 19:16:29.9: _train param, Dropping bad and constant columns: [SPECIES, GRIN_NAME, COLLSITE, ACCENUMB, DOI, GENUS]
#
# ██
# 19:16:34.40: _train param, Dropping bad and constant columns: [SPECIES, GRIN_NAME, COLLSITE, ACCENUMB, DOI, GENUS]
#
# ██
# 19:16:38.891: _train param, Dropping bad and constant columns: [SPECIES, GRIN_NAME, COLLSITE, ACCENUMB, DOI, GENUS]
#
# █
# 19:16:43.349: _train param, Dropping bad and constant columns: [SPECIES, GRIN_NAME, COLLSITE, ACCENUMB, DOI, GENUS]
#
# ████
# 19:16:50.237: _train param, Dropping unused columns: [SPECIES, GRIN_NAME, COLLSITE, ACCENUMB, DOI, GENUS]
#
# ██
# 19:16:52.5: _train param, Dropping unused columns: [SPECIES, GRIN_NAME, COLLSITE, ACCENUMB, DOI, GENUS]
#
# ███████████████████████████████████████████| (done) 100%
# model_id                                                      auc    logloss     aucpr    mean_per_class_error      rmse        mse
# -------------------------------------------------------  --------  ---------  --------  ----------------------  --------  ---------
# StackedEnsemble_AllModels_1_AutoML_1_20251105_191602     0.98982    0.115622  0.978799               0.0526996  0.183368  0.0336239
# StackedEnsemble_BestOfFamily_1_AutoML_1_20251105_191602  0.989778   0.115885  0.978527               0.0546177  0.18375   0.0337641
# GBM_1_AutoML_1_20251105_191602                           0.989442   0.121531  0.977763               0.0592996  0.186019  0.0346029
# GBM_2_AutoML_1_20251105_191602                           0.989337   0.129816  0.977614               0.051042   0.19146   0.0366568
# GBM_4_AutoML_1_20251105_191602                           0.988994   0.131184  0.977784               0.0556748  0.191721  0.036757
# GBM_3_AutoML_1_20251105_191602                           0.988936   0.131435  0.977248               0.0534641  0.190754  0.0363871
# GBM_5_AutoML_1_20251105_191602                           0.988522   0.134904  0.975333               0.0604869  0.194761  0.0379318
# GBM_grid_1_AutoML_1_20251105_191602_model_1              0.988025   0.134642  0.973766               0.0543924  0.196813  0.0387354
# XRT_1_AutoML_1_20251105_191602                           0.986971   0.153694  0.970423               0.0531883  0.212492  0.0451527
# DRF_1_AutoML_1_20251105_191602                           0.986548   0.17471   0.973015               0.0562937  0.209469  0.0438774
# [10 rows x 7 columns]

# %%
# Mejor modelo
best_model = aml.leader
print(best_model.model_id)

# Importancia de variables
#best_model.varimp_plot()
# Out:
# StackedEnsemble_AllModels_1_AutoML_1_20251105_191602

# %%
# Guardar leaderboard
h2o.export_file(lb, "./dataset_salida/automl_resultados.csv", force=True)

# Guardar el modelo
model_path = h2o.save_model(model=best_model, path="./dataset_salida/best_model_h2o", force=True)
print("Modelo guardado en:", model_path)
# Out:
# Export File progress: |██████████████████████████████████████████████████████████| (done) 100%
# Modelo guardado en: C:\Users\guill\Documents\Introduccion_Accesiones\src\AutoMachine_Learning\dataset_salida\best_model_h2o\StackedEnsemble_AllModels_1_AutoML_1_20251105_191602

# %%
# Obtener los modelos base del ensemble
metalearner = best_model.metalearner()
metalearner_summary = metalearner.varimp(use_pandas=True)
print(metalearner_summary)
# Out:
#                                       variable  relative_importance  \
# 0               GBM_1_AutoML_1_20251105_191602             2.434165
# 1               XRT_1_AutoML_1_20251105_191602             1.879449
# 2               GBM_4_AutoML_1_20251105_191602             0.975938
# 3               GBM_2_AutoML_1_20251105_191602             0.325694
# 4               DRF_1_AutoML_1_20251105_191602             0.030284
# 5               GBM_3_AutoML_1_20251105_191602             0.000000
# 6               GBM_5_AutoML_1_20251105_191602             0.000000
# 7  GBM_grid_1_AutoML_1_20251105_191602_model_1             0.000000
# 8      DeepLearning_1_AutoML_1_20251105_191602             0.000000
# 9               GLM_1_AutoML_1_20251105_191602             0.000000
#
#    scaled_importance  percentage
# 0           1.000000    0.431167
# 1           0.772112    0.332909
# 2           0.400933    0.172869
# 3           0.133801    0.057691
# 4           0.012441    0.005364
# 5           0.000000    0.000000
# 6           0.000000    0.000000
# 7           0.000000    0.000000
# 8           0.000000    0.000000
# 9           0.000000    0.000000

# %%
base_model = h2o.get_model("GBM_1_AutoML_1_20251105_191602")

# %%
# Importancia de variables (Feature Importance)
varimp = base_model.varimp(use_pandas=True)
varimp.head(20)

# Gráfico visual
base_model.varimp_plot(num_of_features=20)

# %%
perf.confusion_matrix().show()
# Out:
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.7129472174328396
#        0    1    Error    Rate
# -----  ---  ---  -------  ------------
# 0      702  0    0        (0.0/702.0)
# 1      0    299  0        (0.0/299.0)
# Total  702  299  0        (0.0/1001.0)

# %%
perf = best_model.model_performance(test_data=hf)
print("AUC:", perf.auc())
perf.confusion_matrix().show()
# Out:
# AUC: 1.0
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.7129472174328396
#        0     1    Error    Rate
# -----  ----  ---  -------  ------------
# 0      2365  0    0        (0.0/2365.0)
# 1      0     992  0        (0.0/992.0)
# Total  2365  992  0        (0.0/3357.0)

# %%
perf_cv = best_model.model_performance(xval=True)
print("AUC (cross-validation):", perf_cv.auc())
# Out:
# AUC (cross-validation): 0.9898204664802563

# %% [markdown]
# ## Analisis ##
# Una vez realizado el Auto Machine Learning, nos arroja que el modelo que mejor predice las accesiones resistentes a sequía es el modelo **Stacked Ensemble(Ensamble apilado)**. Este modelo combina varios modelos de base por ejemplo:
# * GBM (Gradient Boosting Machine): modelos aditivos que optimizan el error gradualmente.
# * DRF (Distributed Random Forest): combinaciones de árboles independientes.
# * GLM (Generalized Linear Model): base lineal interpretable.
# * XRT / XGBoost: árboles de refuerzo más eficientes.
# * DeepLearning: redes neuronales densas.
#
# lo que le permite poder obtener una predicción mas robusta. Este modelo evalúa todos los modelos con métricas AUC, logloss, RMSE, etc.
# ![image.png](attachment:0304b186-9f16-4d78-8b43-5f70e41deb18.png)
#
# La particularidad de este modelos es la superioridad con respecto a otros  debido a :
#
# | Causa                                       | Explicación                                                                                                                              |                                                                                                                         |
# | ------------------------------------------- | ---------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------ |
# | **Diversidad de modelos**                   | Cada algoritmo captura diferentes patrones: GBM aprende interacciones no lineales, DRF maneja ruido, GLM generaliza relaciones lineales. ||
# | **Reducción del sobreajuste**               | La combinación ponderada reduce la varianza individual, creando un modelo más estable.                                                   |                                                        |
# | **Optimización del bias-variance tradeoff** | Se equilibran sesgo (modelos simples) y varianza (modelos complejos).                                                                    |                        |
#
#
#
# Para uso de FIGS, este modelo es muy bueno ya que logra el mayor **AUC** y el menor **RMSE**
#
# | Métrica         | Qué me indica                                                                  | Interpretación ecológica para biologos                                                                                                              |
# | --------------- | ------------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------- |
# | **AUC (0.99)**  | Capacidad de discriminación entre accesiones resistentes y no resistentes | El modelo distingue claramente entre ambientes áridos y húmedos, captando el gradiente de sequía.                                      |
# | **RMSE (0.05)** | Error promedio de predicción                                              | Las probabilidades de resistencia son muy precisas, reflejando una coherencia entre los valores ambientales y la respuesta adaptativa. |
#
#
# Luego, se grafíca las variables que marcacron la mayor importación para el modelo. Hay que recordadr que del dataframe se eliminaron las variables con las cuales se creó la variable objetivo. A continuación se detalla el resultado representado en la gráfica
#
#
# | Variable                            | Fuente                                                 | Interpretación ecológica FIGS                                                                                                                                                                                  |
# | ----------------------------------- | ------------------------------------------------------ | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **ORIGCTY**                         | Passport (país de origen)                              | Altísima importancia: los patrones climáticos nacionales reflejan ambientes adaptativos distintos (e.g. Irán vs Brasil). Muestra que la **geografía macro** explica gran parte de la variación de resistencia. |
# | **bio19**                           | WorldClim – Precipitación del trimestre más frío       | Clave para estrés hídrico invernal. Altos valores → lluvias en meses fríos → ambientes más húmedos; bajos valores → ambientes áridos con déficit en estación seca.                                             |
# | **bio15**                           | WorldClim – Estacionalidad de la precipitación         | Mide la variabilidad de lluvia anual. Valores altos → alta irregularidad (sequías estacionales fuertes). Variable crítica en ambientes semiáridos y tropicales secos.                                          |
# | **MODCF_meanannual**                | MODCF – Media anual de cobertura de nubes              | Captura estabilidad atmosférica; zonas con alta nubosidad tienen menor evaporación y temperaturas más estables.                                                                                                |
# | **bio10**                           | WorldClim – Temperatura media del trimestre más cálido | Relacionada con estrés térmico; altas temperaturas incrementan evapotranspiración y déficit hídrico.                                                                                                           |
# | **DECLONGITUDE**                    | Coordenada geográfica                                  | Indica gradientes longitudinales (Pacífico ↔ Atlántico); útil para separar ambientes costeros y continentales.                                                                                                 |
# | **bio14**                           | WorldClim – Precipitación del mes más seco             | Determina si hay “sequías absolutas” (<40 mm). Factor clave de presión selectiva natural en frijol.                                                                                                            |
# | **bio1**                            | WorldClim – Temperatura media anual                    | Refleja energía disponible; controla fenología y fisiología de la planta.                                                                                                                                      |
# | **bio9**                            | WorldClim – Temperatura del trimestre más seco         | Relaciona calor extremo con déficit hídrico.                                                                                                                                                                   |
# | **PHIHOX_M_sl1**                    | SoilGrids – pH del suelo (0–5 cm)                      | Influye en disponibilidad de nutrientes; correlaciona con zonas áridas o húmedas.                                                                                                                              |
# | **srad_5 / srad_9**                 | WorldClim – Radiación solar mensual                    | Afecta fotosíntesis y evapotranspiración; altos valores agravan el estrés por sequía.                                                                                                                          |
# | **current_30arcsec_continentality** | WorldClim – Índice de continentalidad                  | Mide la amplitud térmica anual; valores altos → zonas interiores secas con oscilación térmica fuerte.                                                                                                          |
# | **MODCF_CloudForestPrediction**     | MODCF – Probabilidad de bosque nublado                 | Ambientes húmedos de montaña (microclimas estables, menor déficit hídrico).                                                                                                                                    |
#
# Por último realizo validación cruzada, cuyo resultado fue: **AUC (cross-validation): 0.9898204664802563**.  Esto me permite deducir que el modelo no está memorizando los datos, tiene una buena separación de clases, las variables climáticas y edáficas elegidas son muy discriminativas (tienen verdadero poder predictivo).
#
# ### Se puede decir que el modelo entiende el gradiente ambiental global de adaptación del Phaseolus *vulgaris# *rente al estrés hídrico. ###
#
# # ************************************************************************************************************************************************************

# %% [markdown]
# ## Probando el modelo ##
# Con datos imaginarios de datos climaticos referentes a una accesión, voy a probar el modelo con estos datos.
# # ************************************************************************************************************************************************************

# %%
nueva = h2o.H2OFrame({
    "bio1": [230.5],
    "bio12": [1200.0],
    "bio15": [85.2],
    "bio19": [200.1],
    "AWCh1_M_sl1": [13.7],
    "MODCF_meanannual": [0.45],
    
})

prediccion = best_model.predict(nueva)
print(prediccion)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
#   predict        p0         p1
#         0  0.967038  0.0329619
# [1 row x 3 columns]
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'CURATION': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'ORIGCTY': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'DECLATITUDE': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'DECLONGITUDE': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'SAMPSTAT': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'ELEVATION': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'COLLSRC': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'MODCF_CloudForestPrediction': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'MODCF_seasonality_concentration': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'current_30arcsec_continentality': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'AWCh1_M_sl2': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'AWCtS_M_sl1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'CECSOL_M_sl1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'CECSOL_M_sl2': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'CLYPPT_M_sl1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'CRFVOL_M_sl1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'BDRICM_M': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'ORCDRC_M_sl1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'ORCDRC_M_sl2': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'OCDENS_M_sl1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'OCSTHA_M_sd1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'PHIHOX_M_sl1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'PHIKCL_M_sl1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'BDRLOG_M': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'SNDPPT_M_sl1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'SLTPPT_M_sl1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'SLGWRB': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'WWP_M_sl1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'ACDWRB_M_ss': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'bio10': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'bio13': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'bio14': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'bio18': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'bio2': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'bio3': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'bio8': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'bio9': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'prec_1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'prec_10': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'prec_11': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'prec_4': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'prec_5': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'prec_6': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'prec_7': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'srad_1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'srad_10': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'srad_3': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'srad_4': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'srad_5': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'srad_9': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'wind_1': substituting in a column of NaN
#   warnings.warn(w)
# C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\h2o\job.py:81: UserWarning: Test/Validation dataset is missing column 'wind_10': substituting in a column of NaN
#   warnings.warn(w)
