# %% [markdown]
# # Rasters con valores bioclimáticos y precipitación anual
#
# ## bio *Bioclimáticos*
# ## prec *Precipitación*
# # _________________________________________________________________________________________________________________

# %% [markdown]
# **Caragando librería e importando paquetes para uso en el código**

# %%
# Librerías y paquetes necesarios para poder operar los rasters.
# !pip install geopandas rasterio pandas tqdm

import geopandas as gpd
import geopandas as gpf
import pandas as pd
import rasterio
import glob
import os
from tqdm import tqdm
import numpy as np
import pandas as pd
# Out:
# Requirement already satisfied: geopandas in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (1.1.1)
# Requirement already satisfied: rasterio in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (1.4.3)
# Requirement already satisfied: pandas in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (2.2.2)
# Requirement already satisfied: tqdm in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (4.67.1)
# Requirement already satisfied: numpy>=1.24 in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from geopandas) (24.1)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from geopandas) (2.1.1)
# Requirement already satisfied: affine in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from rasterio) (24.2.0)
# Requirement already satisfied: certifi in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from rasterio) (2024.7.4)
# Requirement already satisfied: click>=4.0 in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from rasterio) (8.3.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from rasterio) (1.1.1.2)
# Requirement already satisfied: pyparsing in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from rasterio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: colorama in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\guill\miniconda3\envs\python_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# # *********************************************************************************************************************
# # DIRECTORIOS
# ## DEFINIENDO DIRECTORIOS
# Se definen las rutas para la obtención de los datos (archivos .tiff) que contienen tod la información climática desde el año 1970 hasta el añ0 2000.
# # *********************************************************************************************************************

# %%
# Verifico si existe la carpeta
#ruta linux root_dir = "/home/guillermo/capas/"  Esta ruta es si ejecuto el código en servidor linux 
root_dir = "capas/"
if os.path.exists(root_dir) and os.path.isdir(root_dir): #Verificación si es una carpeta y no un archivo.
    print(f"La carpeta {root_dir} existe.")
    
    # Buscar todos los .tif en subcarpetas
    archivos = []
    for carpeta, subcarpetas, files in os.walk(root_dir):
        for f in files:
            if f.endswith(".tif"):
                archivos.append(os.path.join(carpeta, f))
    
    if archivos:
        print(f"Se encontraron {len(archivos)} archivos .tif en {root_dir} (incluyendo subcarpetas).")
    else:
        print(f"No se encontraron archivos .tif en {root_dir}.")
else:
    print(f"La carpeta {root_dir} no existe.")
# Out:
# La carpeta capas/ existe.
# Se encontraron 232 archivos .tif en capas/ (incluyendo subcarpetas).

# %% [markdown]
# # *********************************************************************************************************************
# ## Listando los archivos.
# Se crean una lista con los archivos **.tiff** y a su vez se crea la metadata del diccionario a partir de los acrónimos
# # *********************************************************************************************************************

# %%
# Listando los archivos .tif en subcarpetas
raster_files = glob.glob(root_dir + "/**/*.tif", recursive=True)

# Creando los acrónimos automáticos (nombre del archivo sin extensión) para crear el diccionario
acronyms = [f.split("\\")[-1].replace(".tif", "") for f in raster_files]  # Windows path
# Si estoy Linux/Mac cambia a: f.split("/")[-1]

# %% [markdown]
# # *********************************************************************************************************************
# ## Obteniendo la información de las accesiones.
# Se obtiene la información de las accesiones que han sido previamente extraida y transformada
# # *********************************************************************************************************************

# %%
# Cargargando accesiones que ya fueron limpiadas (ejemplo CSV con lon y lat)
file_path = "./dataset_entrada/Dataset_Frijol.csv"

# Verificar si el archivo existe antes de cargarlo
if os.path.exists(file_path):
    try:
        accesiones = pd.read_csv(file_path)
        print(f"El archivo fue cargado correctamente: {file_path}")
        print(f"El dataset tiene {accesiones.shape[0]} filas y {accesiones.shape[1]} columnas.")
    except Exception as e:
        print(f"Error al cargar el archivo: {e}")
else:
    print(f"El archivo no existe en la ruta: {file_path}")
# Out:
# El archivo fue cargado correctamente: ./dataset_entrada/Dataset_Frijol.csv
# El dataset tiene 3357 filas y 15 columnas.

# %% [markdown]
# # *********************************************************************************************************************
# ## Convirtiendo a GeoDataframe.
# En este paso lo que hago es transformar el dataframe convencional de pandas (accesiones) en un GeoDataFrame de geopandas (gdf). Esto permite generar una estructura espacial para poder de manejar coordenadas geográficas. En otras palabras, lo que se hace aquí es transformar la tabla de datos tabulares en una capa geográfica donde cada registro se representa como un punto en el espacio (latitud y longitud).
# Pandas maneja números y textos mientras Geopandas maneja geometrías. Esto me permite representar cada accesión como un punto geográfico dentro del sistema de referencia WGS84 (EPSG:4326), compatible con las capas raster de WorldClim y otras.
# De esta forma, puedo realizar análisis espaciales, como la extracción de variables climáticas o la visualización de patrones ecológicos.
#
# # *********************************************************************************************************************

# %%
# Convirtiendo las accesiones accesiones a GeoDataFrame

gdf = gpd.GeoDataFrame(
    accesiones,
    geometry=gpd.points_from_xy(accesiones.DECLONGITUDE, accesiones.DECLATITUDE), #Esta parte crea una columna de geometría usando las coordenadas x (longitud) y y (latitud).
    #crs significa Coordinate Reference System (Sistema de Referencia de Coordenadas). EPSG:4326 corresponde al sistema WGS84, usado por GPS y por la mayoría de capas globales (incluido WorldClim).
    crs="EPSG:4326" 
)

# %% [markdown]
# # *********************************************************************************************************************
# ## Extrayendo los valores de las capas rasters.
# En este punto extraigo los valores de la capa rasters en los puntos de ubicación de las accesiones.
# Por cada accesión (punto), busco en qué celda del raster cae y obtengo el valor de esa celda.
# Esto constituye el enlace entre los datos genéticos/geográficos y los datos ambientales lo que permite construir una base enriquecida con variables climáticas que caracterizan el ambiente de origen de cada accesión.
# En este paso o que hago es extarer del cada raster el valor asociado a cada punto de coordenada que se le crea a cada accesión  (gdf), esto me permite obtener todas las variables para cada accesión.
# # *********************************************************************************************************************

# %%
# Extrayendo los valores de los rasters en puntos
def extraer_raster(rfile, gdf):
    #abre el archivo raster en modo lectura. El prefijo with asegura que el archivo se cierre automáticamente al finalizar.src es el objeto raster (una matriz de valores distribuidos en el espacio).
    with rasterio.open(rfile) as src:
        valores = [x[0] for x in src.sample(zip(gdf.geometry.x, gdf.geometry.y))]
    return valores

# %% [markdown]
# # *********************************************************************************************************************
# ## Extrayendo los valores de los rasters
# Este bloque de código recorre automáticamente todas las capas raster para extraer sus valores climáticos en las coordenadas de las accesiones.
# Luego, va almacenando los resultados en un DataFrame estructurado, donde cada columna representa una variable ambiental (por ejemplo, bio1, bio2, prec1, etc.), y cada fila corresponde a una accesión.
# Aquí es donde se crea la matriz ambiental completa de todas las accesiones y variables.
# # *********************************************************************************************************************

# %%
# Extrayendo los valores de todos los rasters 
valores = pd.DataFrame()

for i, rfile in enumerate(tqdm(raster_files, desc="Extrayendo rasters")):
    try:
        valores[acronyms[i]] = extraer_raster(rfile, gdf)
    except Exception as e:
        print(f"Error en {rfile}: {e}")
        valores[acronyms[i]] = [None] * len(gdf)
# Out:
# Extrayendo rasters:  43%|█████████████████████████▊                                  | 100/232 [01:42<03:36,  1.64s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  44%|██████████████████████████                                  | 101/232 [01:43<03:31,  1.61s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  44%|██████████████████████████▍                                 | 102/232 [01:45<03:27,  1.59s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  44%|██████████████████████████▋                                 | 103/232 [01:47<03:27,  1.61s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  45%|██████████████████████████▉                                 | 104/232 [01:48<03:29,  1.64s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  45%|███████████████████████████▏                                | 105/232 [01:50<03:29,  1.65s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  46%|███████████████████████████▍                                | 106/232 [01:52<03:27,  1.65s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  46%|███████████████████████████▋                                | 107/232 [01:53<03:25,  1.65s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  47%|███████████████████████████▉                                | 108/232 [01:55<03:23,  1.64s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  47%|████████████████████████████▏                               | 109/232 [01:57<03:25,  1.67s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  47%|████████████████████████████▍                               | 110/232 [01:58<03:20,  1.64s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  48%|████████████████████████████▋                               | 111/232 [02:00<03:17,  1.63s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  48%|████████████████████████████▉                               | 112/232 [02:01<03:14,  1.62s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  49%|█████████████████████████████▏                              | 113/232 [02:03<03:09,  1.60s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  49%|█████████████████████████████▍                              | 114/232 [02:04<03:08,  1.59s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  50%|█████████████████████████████▋                              | 115/232 [02:06<03:08,  1.61s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:
/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  88%|█████████████████████████████████████████████████████       | 205/232 [05:37<00:59,  2.20s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  89%|█████████████████████████████████████████████████████▎      | 206/232 [05:39<00:58,  2.23s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  89%|█████████████████████████████████████████████████████▌      | 207/232 [05:41<00:55,  2.20s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  90%|█████████████████████████████████████████████████████▊      | 208/232 [05:44<00:53,  2.23s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  90%|██████████████████████████████████████████████████████      | 209/232 [05:46<00:49,  2.16s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  91%|██████████████████████████████████████████████████████▎     | 210/232 [05:48<00:45,  2.07s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  91%|██████████████████████████████████████████████████████▌     | 211/232 [05:50<00:42,  2.02s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  91%|██████████████████████████████████████████████████████▊     | 212/232 [05:51<00:39,  1.98s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  92%|███████████████████████████████████████████████████████     | 213/232 [05:53<00:37,  2.00s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  92%|███████████████████████████████████████████████████████▎    | 214/232 [05:56<00:36,  2.02s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  93%|███████████████████████████████████████████████████████▌    | 215/232 [05:58<00:36,  2.14s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  93%|███████████████████████████████████████████████████████▊    | 216/232 [06:01<00:36,  2.27s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  94%|████████████████████████████████████████████████████████    | 217/232 [06:03<00:32,  2.20s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  94%|████████████████████████████████████████████████████████▍   | 218/232 [06:05<00:31,  2.24s/it]C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\rasterio\__init__.py:368: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  94%|████████████████████████████████████████████████████████▋   | 219/232 [06:05<00:20,  1.61s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  95%|████████████████████████████████████████████████████████▉   | 220/232 [06:07<00:20,  1.67s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  95%|█████████████████████████████████████████████████████████▏  | 221/232 [06:09<00:19,  1.75s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  96%|█████████████████████████████████████████████████████████▍  | 222/232 [06:11<00:18,  1.83s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  96%|█████████████████████████████████████████████████████████▋  | 223/232 [06:13<00:16,  1.84s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  97%|█████████████████████████████████████████████████████████▉  | 224/232 [06:15<00:15,  1.89s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  97%|██████████████████████████████████████████████████████████▏ | 225/232 [06:16<00:12,  1.84s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  97%|██████████████████████████████████████████████████████████▍ | 226/232 [06:18<00:11,  1.85s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  98%|██████████████████████████████████████████████████████████▋ | 227/232 [06:20<00:09,  1.84s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  98%|██████████████████████████████████████████████████████████▉ | 228/232 [06:22<00:07,  1.84s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  99%|███████████████████████████████████████████████████████████▏| 229/232 [06:24<00:05,  1.85s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters:  99%|███████████████████████████████████████████████████████████▍| 230/232 [06:26<00:03,  1.85s/it]C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters: 100%|███████████████████████████████████████████████████████████▋| 231/232 [06:27<00:01,  1.80s/it]C:\Users\guill\miniconda3\envs\python_env\Lib\site-packages\rasterio\__init__.py:368: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\guill\AppData\Local\Temp\ipykernel_9648\1106133152.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   valores[acronyms[i]] = extraer_raster(rfile, gdf)
# Extrayendo rasters: 100%|████████████████████████████████████████████████████████████| 232/232 [06:28<00:00,  1.67s/it]

# %%
valores.shape
# Out:
# (3357, 232)

# %% [markdown]
# # Uniendo la información
# Una vez que he obtenido toda la información lo que hago es unir las dos fuentes en un Dataframe. Hago una integración de los datos (Accesiones <-> datos climáticos)
# # *********************************************************************************************************************

# %%
# Limpiar nombres de columnas (quita rutas y extensiones para claridad en la metadata)
valores.columns = [str(col).split('/')[-1].split('\\')[-1].split('.')[0] for col in valores.columns]

# Detectar columnas numéricas
num_cols = valores.select_dtypes(include=[np.number]).columns

# Reemplazar valores inválidos solo en columnas numéricas
valores[num_cols] = valores[num_cols].replace([-3.4e+38, 3.4e+38], np.nan)

# Limpiar valores fuera de rango (solo numéricos)
valores[num_cols] = valores[num_cols].apply(
    lambda col: col.apply(lambda x: np.nan if isinstance(x, (int, float)) and (x < -1e5 or x > 1e5) else x)
)

print("Limpieza completada: nombres corregidos y valores extremos reemplazados.")
# Out:
# Limpieza completada: nombres corregidos y valores extremos reemplazados.

# %% [markdown]
# ## Uniendo accesiones con variables ##
# Lo que hago en este punto es crear la matriz ambiental, donde cada fila representa una accesión y cada columna representa una variable ambiental.
# Esta esla base del enfoque FIGS: vincular diversidad genética ↔ ambiente de origen.
# # *********************************************************************************************************************

# %%
# Uniendo las accesiones con los valores climáticos valores climáticos
resultado = pd.concat([accesiones, valores], axis=1)

# %% [markdown]
# ## Guardando resultados ##
# Una vez tengo asociada las accesiones con sus valores climáticos respectivos, procedo a guardar el nuevo .
# # *********************************************************************************************************************

# %%
# Guardar el dataset limpio en un nuevo archivo Excel
# Este archivo es eld ataset para las siguientes fases (FIGS y ML)
output_filename_excel = './dataset_salida/accesiones_con_worldclim.xlsx'
resultado.to_excel(output_filename_excel, index=False)
output_filename_csv = './dataset_salida/accesiones_con_worldclim.csv'
resultado.to_csv(output_filename_csv, index=False)
print(f"Dataset limpio guardado ")
# Out:
# Dataset limpio guardado

# %%
resultado.head()
# Out:
#               DOI ACCENUMB CURATION      GENUS   SPECIES           GRIN_NAME  \
# 0  10.18730/JKECH   G16570     FULL  Phaseolus  vulgaris  Phaseolus vulgaris
# 1  10.18730/JKEKR   G16576     FULL  Phaseolus  vulgaris  Phaseolus vulgaris
# 2  10.18730/JZXX0     G990     FULL  Phaseolus  vulgaris  Phaseolus vulgaris
# 3  10.18730/JZXWU     G989     FULL  Phaseolus  vulgaris  Phaseolus vulgaris
# 4  10.18730/JZXT$     G987     FULL  Phaseolus  vulgaris  Phaseolus vulgaris
#
#    SAMPSTAT   ACQDATE ORIGCTY  \
# 0       300  19780101     IRN
# 1       300  19780101     IRN
# 2       300  19700901     IRN
# 3       300  19700901     IRN
# 4       300  19700901     IRN
#
#                                           COLLSITE  ...  wind_12  wind_2  \
# 0                                  KARAJ - MARKAZI  ...      2.0     2.5
# 1  KERMANSHAH CHAMCHAL - KERMANSHAH - KERMANSHAHAN  ...      1.7     2.5
# 2                                AHWAZ - KHUZESTAN  ...      1.8     3.0
# 3                                   KAZERUN - FARS  ...      1.8     2.5
# 4                                    SHIRAZ - FARS  ...      1.9     2.7
#
#    wind_3  wind_4  wind_5  wind_6  wind_7  wind_8  wind_9  wind_annual
# 0     3.2     3.5     3.0     2.8     2.9     2.7     2.5          255
# 1     2.9     2.4     2.1     2.6     2.5     2.4     2.4          255
# 2     2.8     2.9     2.8     3.7     3.5     3.1     2.6          255
# 3     3.1     3.4     3.5     3.2     3.2     3.0     2.5          255
# 4     3.0     2.3     2.5     2.7     2.2     1.9     2.2          255
#
# [5 rows x 247 columns]
